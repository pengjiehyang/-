# %% [markdown]
# <a href="https://colab.research.google.com/github/pengjiehyang/-Exquisite-Accounting/blob/main/Open_WebUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Open WebUI
# This is my first notebook so it is probably really messy. Anyways, I wanted to give people the opportunity to try Open WebUI without the need of high-end hardware.
#
# Check my [GitHub](https://github.com/Axenide) 👈

# %% [markdown]
# ## Dependencies
# Here we will install Ollama:

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %% [markdown]
# ## Installing Open WebUI
# Now, Open WebUI needs Python 3.11 so we have to install it in a venv and generate the script to run it asynchronously because Colab won't let you run multiple codeblocks.

# %%
# !sudo apt-get update
# !sudo apt-get install -y python3.11 python3.11-venv python3.11-dev

# Create and activate a virtual environment using Python 3.11
# !python3.11 -m venv venv
# !source venv/bin/activate

# Upgrade pip within the virtual environment
# !venv/bin/python -m pip install --upgrade pip

# Install Open WebUI within the virtual environment
# !venv/bin/pip install open-webui

# Create a script to start both servers asynchronously and expose them using localtunnel
with open('start_servers.py', 'w') as f:
    f.write('''
import subprocess
import threading
import os
import time

def start_ollama():
    subprocess.run(['ollama', 'serve'], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

def start_open_webui():
    subprocess.run(['venv/bin/open-webui', 'serve', '--port', '8081'], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

# Start servers in separate threads
threading.Thread(target=start_ollama).start()
time.sleep(5)
threading.Thread(target=start_open_webui).start()
''')
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:10 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.11 is already the newest version (3.11.13-1+jammy1).
# python3.11-dev is already the newest version (3.11.13-1+jammy1).
# python3.11-venv is already the newest version (3.11.13-1+jammy1).
# 0 upgraded, 0 newly installed, 0 to remove and 51 not upgraded.
# Requirement already satisfied: pip in ./venv/lib/python3.11/site-packages (25.1.1)
# Requirement already satisfied: open-webui in ./venv/lib/python3.11/site-packages (0.6.15)
# Requirement already satisfied: accelerate in ./venv/lib/python3.11/site-packages (from open-webui) (1.8.1)
# Requirement already satisfied: aiocache in ./venv/lib/python3.11/site-packages (from open-webui) (0.12.3)
# Requirement already satisfied: aiofiles in ./venv/lib/python3.11/site-packages (from open-webui) (24.1.0)
# Requirement already satisfied: aiohttp==3.11.11 in ./venv/lib/python3.11/site-packages (from open-webui) (3.11.11)
# Requirement already satisfied: alembic==1.14.0 in ./venv/lib/python3.11/site-packages (from open-webui) (1.14.0)
# Requirement already satisfied: anthropic in ./venv/lib/python3.11/site-packages (from open-webui) (0.57.1)
# Requirement already satisfied: apscheduler==3.10.4 in ./venv/lib/python3.11/site-packages (from open-webui) (3.10.4)
# Requirement already satisfied: argon2-cffi==23.1.0 in ./venv/lib/python3.11/site-packages (from open-webui) (23.1.0)
# Requirement already satisfied: asgiref==3.8.1 in ./venv/lib/python3.11/site-packages (from open-webui) (3.8.1)
# Requirement already satisfied: async-timeout in ./venv/lib/python3.11/site-packages (from open-webui) (5.0.1)
# Requirement already satisfied: authlib==1.4.1 in ./venv/lib/python3.11/site-packages (from open-webui) (1.4.1)
# Requirement already satisfied: azure-ai-documentintelligence==1.0.2 in ./venv/lib/python3.11/site-packages (from open-webui) (1.0.2)
# Requirement already satisfied: azure-identity==1.20.0 in ./venv/lib/python3.11/site-packages (from open-webui) (1.20.0)
# Requirement already satisfied: azure-storage-blob==12.24.1 in ./venv/lib/python3.11/site-packages (from open-webui) (12.24.1)
# Requirement already satisfied: bcrypt==4.3.0 in ./venv/lib/python3.11/site-packages (from open-webui) (4.3.0)
# Requirement already satisfied: black==25.1.0 in ./venv/lib/python3.11/site-packages (from open-webui) (25.1.0)
# Requirement already satisfied: boto3==1.35.53 in ./venv/lib/python3.11/site-packages (from open-webui) (1.35.53)
# Requirement already satisfied: chromadb==0.6.3 in ./venv/lib/python3.11/site-packages (from open-webui) (0.6.3)
# Requirement already satisfied: colbert-ai==0.2.21 in ./venv/lib/python3.11/site-packages (from open-webui) (0.2.21)
# Requirement already satisfied: docker~=7.1.0 in ./venv/lib/python3.11/site-packages (from open-webui) (7.1.0)
# Requirement already satisfied: docx2txt==0.8 in ./venv/lib/python3.11/site-packages (from open-webui) (0.8)
# Requirement already satisfied: duckduckgo-search==8.0.2 in ./venv/lib/python3.11/site-packages (from open-webui) (8.0.2)
# Requirement already satisfied: einops==0.8.1 in ./venv/lib/python3.11/site-packages (from open-webui) (0.8.1)
# Requirement already satisfied: elasticsearch==9.0.1 in ./venv/lib/python3.11/site-packages (from open-webui) (9.0.1)
# Requirement already satisfied: extract-msg in ./venv/lib/python3.11/site-packages (from open-webui) (0.54.1)
# Requirement already satisfied: fake-useragent==2.1.0 in ./venv/lib/python3.11/site-packages (from open-webui) (2.1.0)
# Requirement already satisfied: fastapi==0.115.7 in ./venv/lib/python3.11/site-packages (from open-webui) (0.115.7)
# Requirement already satisfied: faster-whisper==1.1.1 in ./venv/lib/python3.11/site-packages (from open-webui) (1.1.1)
# Requirement already satisfied: firecrawl-py==1.12.0 in ./venv/lib/python3.11/site-packages (from open-webui) (1.12.0)
# Requirement already satisfied: fpdf2==2.8.2 in ./venv/lib/python3.11/site-packages (from open-webui) (2.8.2)
# Requirement already satisfied: ftfy==6.2.3 in ./venv/lib/python3.11/site-packages (from open-webui) (6.2.3)
# Requirement already satisfied: gcp-storage-emulator>=2024.8.3 in ./venv/lib/python3.11/site-packages (from open-webui) (2024.8.3)
# Requirement already satisfied: google-api-python-client in ./venv/lib/python3.11/site-packages (from open-webui) (2.175.0)
# Requirement already satisfied: google-auth-httplib2 in ./venv/lib/python3.11/site-packages (from open-webui) (0.2.0)
# Requirement already satisfied: google-auth-oauthlib in ./venv/lib/python3.11/site-packages (from open-webui) (1.2.2)
# Requirement already satisfied: google-cloud-storage==2.19.0 in ./venv/lib/python3.11/site-packages (from open-webui) (2.19.0)
# Requirement already satisfied: google-genai==1.15.0 in ./venv/lib/python3.11/site-packages (from open-webui) (1.15.0)
# Requirement already satisfied: google-generativeai==0.8.5 in ./venv/lib/python3.11/site-packages (from open-webui) (0.8.5)
# Requirement already satisfied: googleapis-common-protos==1.63.2 in ./venv/lib/python3.11/site-packages (from open-webui) (1.63.2)
# Requirement already satisfied: langchain-community==0.3.23 in ./venv/lib/python3.11/site-packages (from open-webui) (0.3.23)
# Requirement already satisfied: langchain==0.3.24 in ./venv/lib/python3.11/site-packages (from open-webui) (0.3.24)
# Requirement already satisfied: langfuse==2.44.0 in ./venv/lib/python3.11/site-packages (from open-webui) (2.44.0)
# Requirement already satisfied: ldap3==2.9.1 in ./venv/lib/python3.11/site-packages (from open-webui) (2.9.1)
# Requirement already satisfied: loguru==0.7.3 in ./venv/lib/python3.11/site-packages (from open-webui) (0.7.3)
# Requirement already satisfied: markdown==3.7 in ./venv/lib/python3.11/site-packages (from open-webui) (3.7)
# Requirement already satisfied: moto>=5.0.26 in ./venv/lib/python3.11/site-packages (from moto[s3]>=5.0.26->open-webui) (5.1.8)
# Requirement already satisfied: nltk==3.9.1 in ./venv/lib/python3.11/site-packages (from open-webui) (3.9.1)
# Requirement already satisfied: onnxruntime==1.20.1 in ./venv/lib/python3.11/site-packages (from open-webui) (1.20.1)
# Requirement already satisfied: openai in ./venv/lib/python3.11/site-packages (from open-webui) (1.93.1)
# Requirement already satisfied: opencv-python-headless==4.11.0.86 in ./venv/lib/python3.11/site-packages (from open-webui) (4.11.0.86)
# Requirement already satisfied: openpyxl==3.1.5 in ./venv/lib/python3.11/site-packages (from open-webui) (3.1.5)
# Requirement already satisfied: opensearch-py==2.8.0 in ./venv/lib/python3.11/site-packages (from open-webui) (2.8.0)
# Requirement already satisfied: pandas==2.2.3 in ./venv/lib/python3.11/site-packages (from open-webui) (2.2.3)
# Requirement already satisfied: passlib==1.7.4 in ./venv/lib/python3.11/site-packages (from passlib[bcrypt]==1.7.4->open-webui) (1.7.4)
# Requirement already satisfied: peewee-migrate==1.12.2 in ./venv/lib/python3.11/site-packages (from open-webui) (1.12.2)
# Requirement already satisfied: peewee==3.18.1 in ./venv/lib/python3.11/site-packages (from open-webui) (3.18.1)
# Requirement already satisfied: pgvector==0.4.0 in ./venv/lib/python3.11/site-packages (from open-webui) (0.4.0)
# Requirement already satisfied: pillow==11.2.1 in ./venv/lib/python3.11/site-packages (from open-webui) (11.2.1)
# Requirement already satisfied: pinecone==6.0.2 in ./venv/lib/python3.11/site-packages (from open-webui) (6.0.2)
# Requirement already satisfied: playwright==1.49.1 in ./venv/lib/python3.11/site-packages (from open-webui) (1.49.1)
# Requirement already satisfied: psutil in ./venv/lib/python3.11/site-packages (from open-webui) (7.0.0)
# Requirement already satisfied: psycopg2-binary==2.9.9 in ./venv/lib/python3.11/site-packages (from open-webui) (2.9.9)
# Requirement already satisfied: pydantic==2.10.6 in ./venv/lib/python3.11/site-packages (from open-webui) (2.10.6)
# Requirement already satisfied: pydub in ./venv/lib/python3.11/site-packages (from open-webui) (0.25.1)
# Requirement already satisfied: pyjwt==2.10.1 in ./venv/lib/python3.11/site-packages (from pyjwt[crypto]==2.10.1->open-webui) (2.10.1)
# Requirement already satisfied: pymdown-extensions==10.14.2 in ./venv/lib/python3.11/site-packages (from open-webui) (10.14.2)
# Requirement already satisfied: pymilvus==2.5.0 in ./venv/lib/python3.11/site-packages (from open-webui) (2.5.0)
# Requirement already satisfied: pymongo in ./venv/lib/python3.11/site-packages (from open-webui) (4.13.2)
# Requirement already satisfied: pymysql==1.1.1 in ./venv/lib/python3.11/site-packages (from open-webui) (1.1.1)
# Requirement already satisfied: pypandoc==1.15 in ./venv/lib/python3.11/site-packages (from open-webui) (1.15)
# Requirement already satisfied: pypdf==4.3.1 in ./venv/lib/python3.11/site-packages (from open-webui) (4.3.1)
# Requirement already satisfied: pytest-docker~=3.1.1 in ./venv/lib/python3.11/site-packages (from open-webui) (3.1.2)
# Requirement already satisfied: pytest~=8.3.2 in ./venv/lib/python3.11/site-packages (from open-webui) (8.3.5)
# Requirement already satisfied: python-jose==3.4.0 in ./venv/lib/python3.11/site-packages (from open-webui) (3.4.0)
# Requirement already satisfied: python-multipart==0.0.20 in ./venv/lib/python3.11/site-packages (from open-webui) (0.0.20)
# Requirement already satisfied: python-pptx==1.0.2 in ./venv/lib/python3.11/site-packages (from open-webui) (1.0.2)
# Requirement already satisfied: python-socketio==5.13.0 in ./venv/lib/python3.11/site-packages (from open-webui) (5.13.0)
# Requirement already satisfied: pytube==15.0.0 in ./venv/lib/python3.11/site-packages (from open-webui) (15.0.0)
# Requirement already satisfied: pyxlsb==1.0.10 in ./venv/lib/python3.11/site-packages (from open-webui) (1.0.10)
# Requirement already satisfied: qdrant-client~=1.12.0 in ./venv/lib/python3.11/site-packages (from open-webui) (1.12.2)
# Requirement already satisfied: rank-bm25==0.2.2 in ./venv/lib/python3.11/site-packages (from open-webui) (0.2.2)
# Requirement already satisfied: rapidocr-onnxruntime==1.4.4 in ./venv/lib/python3.11/site-packages (from open-webui) (1.4.4)
# Requirement already satisfied: redis in ./venv/lib/python3.11/site-packages (from open-webui) (6.2.0)
# Requirement already satisfied: requests==2.32.4 in ./venv/lib/python3.11/site-packages (from open-webui) (2.32.4)
# Requirement already satisfied: restrictedpython==8.0 in ./venv/lib/python3.11/site-packages (from open-webui) (8.0)
# Requirement already satisfied: sentence-transformers==4.1.0 in ./venv/lib/python3.11/site-packages (from open-webui) (4.1.0)
# Requirement already satisfied: sentencepiece in ./venv/lib/python3.11/site-packages (from open-webui) (0.2.0)
# Requirement already satisfied: soundfile==0.13.1 in ./venv/lib/python3.11/site-packages (from open-webui) (0.13.1)
# Requirement already satisfied: sqlalchemy==2.0.38 in ./venv/lib/python3.11/site-packages (from open-webui) (2.0.38)
# Requirement already satisfied: starlette-compress==1.6.0 in ./venv/lib/python3.11/site-packages (from open-webui) (1.6.0)
# Requirement already satisfied: tencentcloud-sdk-python==3.0.1336 in ./venv/lib/python3.11/site-packages (from open-webui) (3.0.1336)
# Requirement already satisfied: tiktoken in ./venv/lib/python3.11/site-packages (from open-webui) (0.9.0)
# Requirement already satisfied: transformers in ./venv/lib/python3.11/site-packages (from open-webui) (4.53.1)
# Requirement already satisfied: unstructured==0.16.17 in ./venv/lib/python3.11/site-packages (from open-webui) (0.16.17)
# Requirement already satisfied: uvicorn==0.34.2 in ./venv/lib/python3.11/site-packages (from uvicorn[standard]==0.34.2->open-webui) (0.34.2)
# Requirement already satisfied: validators==0.35.0 in ./venv/lib/python3.11/site-packages (from open-webui) (0.35.0)
# Requirement already satisfied: xlrd==2.0.1 in ./venv/lib/python3.11/site-packages (from open-webui) (2.0.1)
# Requirement already satisfied: youtube-transcript-api==1.1.0 in ./venv/lib/python3.11/site-packages (from open-webui) (1.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./venv/lib/python3.11/site-packages (from aiohttp==3.11.11->open-webui) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.11/site-packages (from aiohttp==3.11.11->open-webui) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.11/site-packages (from aiohttp==3.11.11->open-webui) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.11/site-packages (from aiohttp==3.11.11->open-webui) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.11/site-packages (from aiohttp==3.11.11->open-webui) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in ./venv/lib/python3.11/site-packages (from aiohttp==3.11.11->open-webui) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./venv/lib/python3.11/site-packages (from aiohttp==3.11.11->open-webui) (1.20.1)
# Requirement already satisfied: Mako in ./venv/lib/python3.11/site-packages (from alembic==1.14.0->open-webui) (1.3.10)
# Requirement already satisfied: typing-extensions>=4 in ./venv/lib/python3.11/site-packages (from alembic==1.14.0->open-webui) (4.14.1)
# Requirement already satisfied: six>=1.4.0 in ./venv/lib/python3.11/site-packages (from apscheduler==3.10.4->open-webui) (1.17.0)
# Requirement already satisfied: pytz in ./venv/lib/python3.11/site-packages (from apscheduler==3.10.4->open-webui) (2025.2)
# Requirement already satisfied: tzlocal!=3.*,>=2.0 in ./venv/lib/python3.11/site-packages (from apscheduler==3.10.4->open-webui) (5.3.1)
# Requirement already satisfied: argon2-cffi-bindings in ./venv/lib/python3.11/site-packages (from argon2-cffi==23.1.0->open-webui) (21.2.0)
# Requirement already satisfied: cryptography in ./venv/lib/python3.11/site-packages (from authlib==1.4.1->open-webui) (45.0.5)
# Requirement already satisfied: isodate>=0.6.1 in ./venv/lib/python3.11/site-packages (from azure-ai-documentintelligence==1.0.2->open-webui) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in ./venv/lib/python3.11/site-packages (from azure-ai-documentintelligence==1.0.2->open-webui) (1.35.0)
# Requirement already satisfied: msal>=1.30.0 in ./venv/lib/python3.11/site-packages (from azure-identity==1.20.0->open-webui) (1.32.3)
# Requirement already satisfied: msal-extensions>=1.2.0 in ./venv/lib/python3.11/site-packages (from azure-identity==1.20.0->open-webui) (1.3.1)
# Requirement already satisfied: click>=8.0.0 in ./venv/lib/python3.11/site-packages (from black==25.1.0->open-webui) (8.2.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in ./venv/lib/python3.11/site-packages (from black==25.1.0->open-webui) (1.1.0)
# Requirement already satisfied: packaging>=22.0 in ./venv/lib/python3.11/site-packages (from black==25.1.0->open-webui) (23.2)
# Requirement already satisfied: pathspec>=0.9.0 in ./venv/lib/python3.11/site-packages (from black==25.1.0->open-webui) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in ./venv/lib/python3.11/site-packages (from black==25.1.0->open-webui) (4.3.8)
# Requirement already satisfied: botocore<1.36.0,>=1.35.53 in ./venv/lib/python3.11/site-packages (from boto3==1.35.53->open-webui) (1.35.99)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in ./venv/lib/python3.11/site-packages (from boto3==1.35.53->open-webui) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in ./venv/lib/python3.11/site-packages (from boto3==1.35.53->open-webui) (0.10.4)
# Requirement already satisfied: build>=1.0.3 in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (0.7.6)
# Requirement already satisfied: numpy>=1.22.5 in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (6.0.3)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (1.34.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (0.55b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (1.34.1)
# Requirement already satisfied: tokenizers>=0.13.2 in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (0.21.2)
# Requirement already satisfied: pypika>=0.48.9 in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (7.7.0)
# Requirement already satisfied: importlib-resources in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (1.67.1)
# Requirement already satisfied: typer>=0.9.0 in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (9.1.2)
# Requirement already satisfied: PyYAML>=6.0.0 in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in ./venv/lib/python3.11/site-packages (from chromadb==0.6.3->open-webui) (14.0.0)
# Requirement already satisfied: bitarray in ./venv/lib/python3.11/site-packages (from colbert-ai==0.2.21->open-webui) (3.5.0)
# Requirement already satisfied: datasets in ./venv/lib/python3.11/site-packages (from colbert-ai==0.2.21->open-webui) (3.6.0)
# Requirement already satisfied: flask in ./venv/lib/python3.11/site-packages (from colbert-ai==0.2.21->open-webui) (3.1.1)
# Requirement already satisfied: git-python in ./venv/lib/python3.11/site-packages (from colbert-ai==0.2.21->open-webui) (1.0.3)
# Requirement already satisfied: python-dotenv in ./venv/lib/python3.11/site-packages (from colbert-ai==0.2.21->open-webui) (1.1.1)
# Requirement already satisfied: ninja in ./venv/lib/python3.11/site-packages (from colbert-ai==0.2.21->open-webui) (1.11.1.4)
# Requirement already satisfied: scipy in ./venv/lib/python3.11/site-packages (from colbert-ai==0.2.21->open-webui) (1.16.0)
# Requirement already satisfied: ujson in ./venv/lib/python3.11/site-packages (from colbert-ai==0.2.21->open-webui) (5.10.0)
# Requirement already satisfied: primp>=0.15.0 in ./venv/lib/python3.11/site-packages (from duckduckgo-search==8.0.2->open-webui) (0.15.0)
# Requirement already satisfied: lxml>=5.3.0 in ./venv/lib/python3.11/site-packages (from duckduckgo-search==8.0.2->open-webui) (6.0.0)
# Requirement already satisfied: elastic-transport<9,>=8.15.1 in ./venv/lib/python3.11/site-packages (from elasticsearch==9.0.1->open-webui) (8.17.1)
# Requirement already satisfied: python-dateutil in ./venv/lib/python3.11/site-packages (from elasticsearch==9.0.1->open-webui) (2.9.0.post0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in ./venv/lib/python3.11/site-packages (from fastapi==0.115.7->open-webui) (0.45.3)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.11/site-packages (from pydantic==2.10.6->open-webui) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in ./venv/lib/python3.11/site-packages (from pydantic==2.10.6->open-webui) (2.27.2)
# Requirement already satisfied: ctranslate2<5,>=4.0 in ./venv/lib/python3.11/site-packages (from faster-whisper==1.1.1->open-webui) (4.6.0)
# Requirement already satisfied: huggingface-hub>=0.13 in ./venv/lib/python3.11/site-packages (from faster-whisper==1.1.1->open-webui) (0.33.2)
# Requirement already satisfied: av>=11 in ./venv/lib/python3.11/site-packages (from faster-whisper==1.1.1->open-webui) (15.0.0)
# Requirement already satisfied: coloredlogs in ./venv/lib/python3.11/site-packages (from onnxruntime==1.20.1->open-webui) (15.0.1)
# Requirement already satisfied: flatbuffers in ./venv/lib/python3.11/site-packages (from onnxruntime==1.20.1->open-webui) (25.2.10)
# Requirement already satisfied: protobuf in ./venv/lib/python3.11/site-packages (from onnxruntime==1.20.1->open-webui) (5.29.5)
# Requirement already satisfied: sympy in ./venv/lib/python3.11/site-packages (from onnxruntime==1.20.1->open-webui) (1.14.0)
# Requirement already satisfied: websockets in ./venv/lib/python3.11/site-packages (from firecrawl-py==1.12.0->open-webui) (15.0.1)
# Requirement already satisfied: nest-asyncio in ./venv/lib/python3.11/site-packages (from firecrawl-py==1.12.0->open-webui) (1.6.0)
# Requirement already satisfied: defusedxml in ./venv/lib/python3.11/site-packages (from fpdf2==2.8.2->open-webui) (0.7.1)
# Requirement already satisfied: fonttools>=4.34.0 in ./venv/lib/python3.11/site-packages (from fpdf2==2.8.2->open-webui) (4.58.5)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in ./venv/lib/python3.11/site-packages (from ftfy==6.2.3->open-webui) (0.2.13)
# Requirement already satisfied: google-auth<3.0dev,>=2.26.1 in ./venv/lib/python3.11/site-packages (from google-cloud-storage==2.19.0->open-webui) (2.40.3)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in ./venv/lib/python3.11/site-packages (from google-cloud-storage==2.19.0->open-webui) (2.25.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in ./venv/lib/python3.11/site-packages (from google-cloud-storage==2.19.0->open-webui) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in ./venv/lib/python3.11/site-packages (from google-cloud-storage==2.19.0->open-webui) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in ./venv/lib/python3.11/site-packages (from google-cloud-storage==2.19.0->open-webui) (1.7.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.11/site-packages (from requests==2.32.4->open-webui) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.11/site-packages (from requests==2.32.4->open-webui) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.11/site-packages (from requests==2.32.4->open-webui) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.11/site-packages (from requests==2.32.4->open-webui) (2025.6.15)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in ./venv/lib/python3.11/site-packages (from google-genai==1.15.0->open-webui) (4.9.0)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in ./venv/lib/python3.11/site-packages (from google-generativeai==0.8.5->open-webui) (0.6.15)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in ./venv/lib/python3.11/site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai==0.8.5->open-webui) (1.26.1)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.55 in ./venv/lib/python3.11/site-packages (from langchain==0.3.24->open-webui) (0.3.68)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in ./venv/lib/python3.11/site-packages (from langchain==0.3.24->open-webui) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in ./venv/lib/python3.11/site-packages (from langchain==0.3.24->open-webui) (0.3.45)
# Requirement already satisfied: greenlet!=0.4.17 in ./venv/lib/python3.11/site-packages (from sqlalchemy==2.0.38->open-webui) (3.1.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./venv/lib/python3.11/site-packages (from langchain-community==0.3.23->open-webui) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in ./venv/lib/python3.11/site-packages (from langchain-community==0.3.23->open-webui) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in ./venv/lib/python3.11/site-packages (from langchain-community==0.3.23->open-webui) (0.4.1)
# Requirement already satisfied: backoff>=1.10.0 in ./venv/lib/python3.11/site-packages (from langfuse==2.44.0->open-webui) (2.2.1)
# Requirement already satisfied: wrapt<2.0,>=1.14 in ./venv/lib/python3.11/site-packages (from langfuse==2.44.0->open-webui) (1.17.2)
# Requirement already satisfied: pyasn1>=0.4.6 in ./venv/lib/python3.11/site-packages (from ldap3==2.9.1->open-webui) (0.4.8)
# Requirement already satisfied: joblib in ./venv/lib/python3.11/site-packages (from nltk==3.9.1->open-webui) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in ./venv/lib/python3.11/site-packages (from nltk==3.9.1->open-webui) (2024.11.6)
# Requirement already satisfied: et-xmlfile in ./venv/lib/python3.11/site-packages (from openpyxl==3.1.5->open-webui) (2.0.0)
# Requirement already satisfied: Events in ./venv/lib/python3.11/site-packages (from opensearch-py==2.8.0->open-webui) (0.5)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas==2.2.3->open-webui) (2025.2)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in ./venv/lib/python3.11/site-packages (from pinecone==6.0.2->open-webui) (0.0.7)
# Requirement already satisfied: pyee==12.0.0 in ./venv/lib/python3.11/site-packages (from playwright==1.49.1->open-webui) (12.0.0)
# Requirement already satisfied: setuptools>69 in ./venv/lib/python3.11/site-packages (from pymilvus==2.5.0->open-webui) (80.9.0)
# Requirement already satisfied: milvus-lite>=2.4.0 in ./venv/lib/python3.11/site-packages (from pymilvus==2.5.0->open-webui) (2.5.1)
# Requirement already satisfied: ecdsa!=0.15 in ./venv/lib/python3.11/site-packages (from python-jose==3.4.0->open-webui) (0.19.1)
# Requirement already satisfied: rsa!=4.1.1,!=4.4,<5.0,>=4.0 in ./venv/lib/python3.11/site-packages (from python-jose==3.4.0->open-webui) (4.9.1)
# Requirement already satisfied: XlsxWriter>=0.5.7 in ./venv/lib/python3.11/site-packages (from python-pptx==1.0.2->open-webui) (3.2.5)
# Requirement already satisfied: bidict>=0.21.0 in ./venv/lib/python3.11/site-packages (from python-socketio==5.13.0->open-webui) (0.23.1)
# Requirement already satisfied: python-engineio>=4.11.0 in ./venv/lib/python3.11/site-packages (from python-socketio==5.13.0->open-webui) (4.12.2)
# Requirement already satisfied: pyclipper>=1.2.0 in ./venv/lib/python3.11/site-packages (from rapidocr-onnxruntime==1.4.4->open-webui) (1.3.0.post6)
# Requirement already satisfied: opencv-python>=4.5.1.48 in ./venv/lib/python3.11/site-packages (from rapidocr-onnxruntime==1.4.4->open-webui) (4.11.0.86)
# Requirement already satisfied: Shapely!=2.0.4,>=1.7.1 in ./venv/lib/python3.11/site-packages (from rapidocr-onnxruntime==1.4.4->open-webui) (2.1.1)
# Requirement already satisfied: torch>=1.11.0 in ./venv/lib/python3.11/site-packages (from sentence-transformers==4.1.0->open-webui) (2.7.1)
# Requirement already satisfied: scikit-learn in ./venv/lib/python3.11/site-packages (from sentence-transformers==4.1.0->open-webui) (1.7.0)
# Requirement already satisfied: cffi>=1.0 in ./venv/lib/python3.11/site-packages (from soundfile==0.13.1->open-webui) (1.17.1)
# Requirement already satisfied: brotli>=1 in ./venv/lib/python3.11/site-packages (from starlette-compress==1.6.0->open-webui) (1.1.0)
# Requirement already satisfied: zstandard>=0.15 in ./venv/lib/python3.11/site-packages (from starlette-compress==1.6.0->open-webui) (0.23.0)
# Requirement already satisfied: chardet in ./venv/lib/python3.11/site-packages (from unstructured==0.16.17->open-webui) (5.2.0)
# Requirement already satisfied: filetype in ./venv/lib/python3.11/site-packages (from unstructured==0.16.17->open-webui) (1.2.0)
# Requirement already satisfied: python-magic in ./venv/lib/python3.11/site-packages (from unstructured==0.16.17->open-webui) (0.4.27)
# Requirement already satisfied: beautifulsoup4 in ./venv/lib/python3.11/site-packages (from unstructured==0.16.17->open-webui) (4.13.4)
# Requirement already satisfied: emoji in ./venv/lib/python3.11/site-packages (from unstructured==0.16.17->open-webui) (2.14.1)
# Requirement already satisfied: python-iso639 in ./venv/lib/python3.11/site-packages (from unstructured==0.16.17->open-webui) (2025.2.18)
# Requirement already satisfied: langdetect in ./venv/lib/python3.11/site-packages (from unstructured==0.16.17->open-webui) (1.0.9)
# Requirement already satisfied: rapidfuzz in ./venv/lib/python3.11/site-packages (from unstructured==0.16.17->open-webui) (3.13.0)
# Requirement already satisfied: unstructured-client in ./venv/lib/python3.11/site-packages (from unstructured==0.16.17->open-webui) (0.32.3)
# Requirement already satisfied: python-oxmsg in ./venv/lib/python3.11/site-packages (from unstructured==0.16.17->open-webui) (0.0.2)
# Requirement already satisfied: html5lib in ./venv/lib/python3.11/site-packages (from unstructured==0.16.17->open-webui) (1.1)
# Requirement already satisfied: h11>=0.8 in ./venv/lib/python3.11/site-packages (from uvicorn==0.34.2->uvicorn[standard]==0.34.2->open-webui) (0.16.0)
# Requirement already satisfied: httptools>=0.6.3 in ./venv/lib/python3.11/site-packages (from uvicorn[standard]==0.34.2->open-webui) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in ./venv/lib/python3.11/site-packages (from uvicorn[standard]==0.34.2->open-webui) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in ./venv/lib/python3.11/site-packages (from uvicorn[standard]==0.34.2->open-webui) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in ./venv/lib/python3.11/site-packages (from anyio<5.0.0,>=4.8.0->google-genai==1.15.0->open-webui) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./venv/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.23->open-webui) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./venv/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.23->open-webui) (0.9.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in ./venv/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai==0.8.5->open-webui) (1.67.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./venv/lib/python3.11/site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage==2.19.0->open-webui) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./venv/lib/python3.11/site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage==2.19.0->open-webui) (0.4.1)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb==0.6.3->open-webui) (1.0.9)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.55->langchain==0.3.24->open-webui) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.55->langchain==0.3.24->open-webui) (3.0.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./venv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.17->langchain==0.3.24->open-webui) (1.0.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./venv/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community==0.3.23->open-webui) (0.4.1)
# Requirement already satisfied: iniconfig in ./venv/lib/python3.11/site-packages (from pytest~=8.3.2->open-webui) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in ./venv/lib/python3.11/site-packages (from pytest~=8.3.2->open-webui) (1.6.0)
# Requirement already satisfied: grpcio-tools>=1.41.0 in ./venv/lib/python3.11/site-packages (from qdrant-client~=1.12.0->open-webui) (1.67.1)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in ./venv/lib/python3.11/site-packages (from qdrant-client~=1.12.0->open-webui) (2.10.1)
# Requirement already satisfied: filelock in ./venv/lib/python3.11/site-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1->open-webui) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./venv/lib/python3.11/site-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1->open-webui) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in ./venv/lib/python3.11/site-packages (from huggingface-hub>=0.13->faster-whisper==1.1.1->open-webui) (1.1.5)
# Requirement already satisfied: safetensors>=0.4.3 in ./venv/lib/python3.11/site-packages (from transformers->open-webui) (0.5.3)
# Requirement already satisfied: pyproject_hooks in ./venv/lib/python3.11/site-packages (from build>=1.0.3->chromadb==0.6.3->open-webui) (1.2.0)
# Requirement already satisfied: pycparser in ./venv/lib/python3.11/site-packages (from cffi>=1.0->soundfile==0.13.1->open-webui) (2.22)
# Requirement already satisfied: fs in ./venv/lib/python3.11/site-packages (from gcp-storage-emulator>=2024.8.3->open-webui) (2.4.16)
# Requirement already satisfied: h2<5,>=3 in ./venv/lib/python3.11/site-packages (from httpx[http2]>=0.20.0->qdrant-client~=1.12.0->open-webui) (4.2.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in ./venv/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client~=1.12.0->open-webui) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in ./venv/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client~=1.12.0->open-webui) (4.1.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in ./venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb==0.6.3->open-webui) (1.8.0)
# Requirement already satisfied: requests-oauthlib in ./venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb==0.6.3->open-webui) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in ./venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb==0.6.3->open-webui) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in ./venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb==0.6.3->open-webui) (0.10)
# Requirement already satisfied: xmltodict in ./venv/lib/python3.11/site-packages (from moto>=5.0.26->moto[s3]>=5.0.26->open-webui) (0.14.2)
# Requirement already satisfied: werkzeug!=2.2.0,!=2.2.1,>=0.5 in ./venv/lib/python3.11/site-packages (from moto>=5.0.26->moto[s3]>=5.0.26->open-webui) (3.1.3)
# Requirement already satisfied: responses!=0.25.5,>=0.15.0 in ./venv/lib/python3.11/site-packages (from moto>=5.0.26->moto[s3]>=5.0.26->open-webui) (0.25.7)
# Requirement already satisfied: Jinja2>=2.10.1 in ./venv/lib/python3.11/site-packages (from moto>=5.0.26->moto[s3]>=5.0.26->open-webui) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.11/site-packages (from Jinja2>=2.10.1->moto>=5.0.26->moto[s3]>=5.0.26->open-webui) (3.0.2)
# Requirement already satisfied: py-partiql-parser==0.6.1 in ./venv/lib/python3.11/site-packages (from moto[s3]>=5.0.26->open-webui) (0.6.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in ./venv/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb==0.6.3->open-webui) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in ./venv/lib/python3.11/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb==0.6.3->open-webui) (3.23.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in ./venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.6.3->open-webui) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in ./venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.6.3->open-webui) (1.34.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in ./venv/lib/python3.11/site-packages (from opentelemetry-sdk>=1.2.0->chromadb==0.6.3->open-webui) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.55b1 in ./venv/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.6.3->open-webui) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.55b1 in ./venv/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.6.3->open-webui) (0.55b1)
# Requirement already satisfied: opentelemetry-util-http==0.55b1 in ./venv/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.6.3->open-webui) (0.55b1)
# Requirement already satisfied: distro>=1.5.0 in ./venv/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb==0.6.3->open-webui) (1.9.0)
# Requirement already satisfied: simple-websocket>=0.10.0 in ./venv/lib/python3.11/site-packages (from python-engineio>=4.11.0->python-socketio==5.13.0->open-webui) (1.1.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./venv/lib/python3.11/site-packages (from rich>=10.11.0->chromadb==0.6.3->open-webui) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./venv/lib/python3.11/site-packages (from rich>=10.11.0->chromadb==0.6.3->open-webui) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb==0.6.3->open-webui) (0.1.2)
# Requirement already satisfied: wsproto in ./venv/lib/python3.11/site-packages (from simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio==5.13.0->open-webui) (1.2.0)
# Requirement already satisfied: networkx in ./venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==4.1.0->open-webui) (3.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in ./venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==4.1.0->open-webui) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in ./venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==4.1.0->open-webui) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in ./venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==4.1.0->open-webui) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in ./venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==4.1.0->open-webui) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in ./venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==4.1.0->open-webui) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in ./venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==4.1.0->open-webui) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in ./venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==4.1.0->open-webui) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in ./venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==4.1.0->open-webui) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in ./venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==4.1.0->open-webui) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in ./venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==4.1.0->open-webui) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in ./venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==4.1.0->open-webui) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in ./venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==4.1.0->open-webui) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in ./venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==4.1.0->open-webui) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in ./venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==4.1.0->open-webui) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in ./venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers==4.1.0->open-webui) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.11/site-packages (from sympy->onnxruntime==1.20.1->open-webui) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in ./venv/lib/python3.11/site-packages (from typer>=0.9.0->chromadb==0.6.3->open-webui) (1.5.4)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./venv/lib/python3.11/site-packages (from anthropic->open-webui) (0.10.0)
# Requirement already satisfied: soupsieve>1.2 in ./venv/lib/python3.11/site-packages (from beautifulsoup4->unstructured==0.16.17->open-webui) (2.7)
# Requirement already satisfied: humanfriendly>=9.1 in ./venv/lib/python3.11/site-packages (from coloredlogs->onnxruntime==1.20.1->open-webui) (10.0)
# Requirement already satisfied: pyarrow>=15.0.0 in ./venv/lib/python3.11/site-packages (from datasets->colbert-ai==0.2.21->open-webui) (20.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in ./venv/lib/python3.11/site-packages (from datasets->colbert-ai==0.2.21->open-webui) (0.3.8)
# Requirement already satisfied: xxhash in ./venv/lib/python3.11/site-packages (from datasets->colbert-ai==0.2.21->open-webui) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in ./venv/lib/python3.11/site-packages (from datasets->colbert-ai==0.2.21->open-webui) (0.70.16)
# Requirement already satisfied: olefile==0.47 in ./venv/lib/python3.11/site-packages (from extract-msg->open-webui) (0.47)
# Requirement already satisfied: compressed-rtf<2,>=1.0.6 in ./venv/lib/python3.11/site-packages (from extract-msg->open-webui) (1.0.7)
# Requirement already satisfied: ebcdic<2,>=1.1.1 in ./venv/lib/python3.11/site-packages (from extract-msg->open-webui) (1.1.1)
# Requirement already satisfied: RTFDE<0.2,>=0.1.1 in ./venv/lib/python3.11/site-packages (from extract-msg->open-webui) (0.1.2.1)
# Requirement already satisfied: red-black-tree-mod<=1.23,>=1.20 in ./venv/lib/python3.11/site-packages (from extract-msg->open-webui) (1.22)
# Requirement already satisfied: lark~=1.1.8 in ./venv/lib/python3.11/site-packages (from RTFDE<0.2,>=0.1.1->extract-msg->open-webui) (1.1.9)
# Requirement already satisfied: oletools>=0.56 in ./venv/lib/python3.11/site-packages (from RTFDE<0.2,>=0.1.1->extract-msg->open-webui) (0.60.2)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in ./venv/lib/python3.11/site-packages (from oletools>=0.56->RTFDE<0.2,>=0.1.1->extract-msg->open-webui) (3.2.3)
# Requirement already satisfied: easygui in ./venv/lib/python3.11/site-packages (from oletools>=0.56->RTFDE<0.2,>=0.1.1->extract-msg->open-webui) (0.98.3)
# Requirement already satisfied: colorclass in ./venv/lib/python3.11/site-packages (from oletools>=0.56->RTFDE<0.2,>=0.1.1->extract-msg->open-webui) (2.2.2)
# Requirement already satisfied: pcodedmp>=1.2.5 in ./venv/lib/python3.11/site-packages (from oletools>=0.56->RTFDE<0.2,>=0.1.1->extract-msg->open-webui) (1.2.6)
# Requirement already satisfied: msoffcrypto-tool in ./venv/lib/python3.11/site-packages (from oletools>=0.56->RTFDE<0.2,>=0.1.1->extract-msg->open-webui) (5.4.2)
# Requirement already satisfied: blinker>=1.9.0 in ./venv/lib/python3.11/site-packages (from flask->colbert-ai==0.2.21->open-webui) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in ./venv/lib/python3.11/site-packages (from flask->colbert-ai==0.2.21->open-webui) (2.2.0)
# Requirement already satisfied: appdirs~=1.4.3 in ./venv/lib/python3.11/site-packages (from fs->gcp-storage-emulator>=2024.8.3->open-webui) (1.4.4)
# Requirement already satisfied: gitpython in ./venv/lib/python3.11/site-packages (from git-python->colbert-ai==0.2.21->open-webui) (3.1.44)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./venv/lib/python3.11/site-packages (from gitpython->git-python->colbert-ai==0.2.21->open-webui) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./venv/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython->git-python->colbert-ai==0.2.21->open-webui) (5.0.2)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in ./venv/lib/python3.11/site-packages (from google-api-python-client->open-webui) (0.22.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in ./venv/lib/python3.11/site-packages (from google-api-python-client->open-webui) (4.2.0)
# Requirement already satisfied: webencodings in ./venv/lib/python3.11/site-packages (from html5lib->unstructured==0.16.17->open-webui) (0.5.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in ./venv/lib/python3.11/site-packages (from pymongo->open-webui) (2.7.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./venv/lib/python3.11/site-packages (from scikit-learn->sentence-transformers==4.1.0->open-webui) (3.6.0)
# Requirement already satisfied: eval-type-backport>=0.2.0 in ./venv/lib/python3.11/site-packages (from unstructured-client->unstructured==0.16.17->open-webui) (0.2.2)

# %% [markdown]
# ## Time to start the servers!
# We will run both Open WebUI and Ollama servers and get the public URL using Pinggy.
#
# To download models, navigate to the Ollama Settings in the Connections tab. Alternatively, you can also download models directly by typing their tag in the model selection dropdown (e.g. mistral-nemo). This action will create a button labeled "Pull [Model Name]" for downloading.

# %%
# Execute the script
# !venv/bin/python start_servers.py & sleep 20; echo | ssh -o StrictHostKeyChecking=no -p 443 -R0:localhost:8081 qr@a.pinggy.io
# Out:
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Allocated port 2 for remote forward to localhost:8081
# You are not authenticated.
# Your tunnel will expire in 60 minutes. Upgrade to Pinggy Pro to get unrestricted tunnels. https://dashboard.pinggy.io
# http://rnbsl-34-143-205-104.a.free.pinggy.link
# https://rnbsl-34-143-205-104.a.free.pinggy.link
# RB: 1146809, SB: 5255827, TC: 102, AC: 1
